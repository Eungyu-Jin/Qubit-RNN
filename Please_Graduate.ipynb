# %%
from Please_Graduate import Quantum_System, Models, Experiment
import numpy as np

#experimental setting
omega_r = 2*np.pi*0.80
kai = -2*np.pi*0.18

#model fit setting
split_ratio = 0.75
time_step = 10
n_samples = 100
n_times = 100
t_i, t_f = 0, 1

#transformer setting
key_dim = 256
num_heads = 4
ff_dim = 128
num_blocks = 1

# %%
experiment = Experiment(qubit_initial=0, cavity_initial=1, superposition=True, n_samples=100, n_times=100, t_i=0, t_f=1)

# %%
experiment.Run_system(model = 'LSTM', epochs=100, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5179 - binary_crossentropy: 0.5297
# train loss: 0.5178614854812622
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5110 - binary_crossentropy: 0.5110
# test loss: 0.5109809041023254
# rmse: 0.09831758489411449
# r2: 0.6008782694226336

# %%
experiment.Run_system(model = 'BiLSTM', epochs=100, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5045 - binary_crossentropy: 0.5160
# train loss: 0.5044959783554077
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5008 - binary_crossentropy: 0.5008
# test loss: 0.5008109211921692
# rmse: 0.07825769327986543
# r2: 0.7841577766567422

# %%
experiment.Run_system(model = 'Transformer', epochs=100, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 28ms/step - loss: 0.4881 - binary_crossentropy: 0.5059
# train loss: 0.48809880018234253
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4929 - binary_crossentropy: 0.4929
# test loss: 0.4928601384162903
# rmse: 0.06724143292710044
# r2: 0.7958383196565966

# %%
experiment.Run_system(model = 'Transformer_conv', epochs=100, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4826 - binary_crossentropy: 0.4988
# train loss: 0.4826273024082184
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4921 - binary_crossentropy: 0.4921
# test loss: 0.49210330843925476
# rmse: 0.05775502310024688
# r2: 0.846731591190421

# %%
experiment.Run_system(model = 'Transformer_conv', epochs=150, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4855 - binary_crossentropy: 0.5002
# train loss: 0.48549404740333557
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4847 - binary_crossentropy: 0.4847
# test loss: 0.484744131565094
# rmse: 0.052189556864285926
# r2: 0.9001245864286161

# %%
experiment = Experiment(qubit_initial=0, cavity_initial=1, superposition=True, n_samples=100, n_times=100, t_i=0, t_f=1)
for e in [10,50,100,150,200]:
    experiment.Run_system(model = 'BiLSTM', epochs=e, batch_size=100)
    print('epochs: {}'.format(e))
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5752 - binary_crossentropy: 0.5774
# train loss: 0.5752028822898865
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5741 - binary_crossentropy: 0.5741
# test loss: 0.5741192102432251
# rmse: 0.17908986760945245
# r2: -0.3501287036723671
# epochs: 10
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5569 - binary_crossentropy: 0.5659
# train loss: 0.5569422245025635
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5524 - binary_crossentropy: 0.5524
# test loss: 0.5524270534515381
# rmse: 0.15228446765144302
# r2: 0.015943071772969886
# epochs: 50
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5074 - binary_crossentropy: 0.5189
# train loss: 0.5073665380477905
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5078 - binary_crossentropy: 0.5078
# test loss: 0.5078467130661011
# rmse: 0.09059880512306881
# r2: 0.6577757551894334
# epochs: 100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5005 - binary_crossentropy: 0.5051
# train loss: 0.5005000829696655
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002806E189C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4920 - binary_crossentropy: 0.4920
# test loss: 0.4920387268066406
# rmse: 0.07383544765294568
# r2: 0.8170502891589182
# epochs: 150
# 3/3 [==============================] - 0s 0s/step - loss: 0.4951 - binary_crossentropy: 0.5026
# train loss: 0.4950723648071289
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4983 - binary_crossentropy: 0.4983
# test loss: 0.4982934594154358
# rmse: 0.06622223557201708
# r2: 0.8168562986078288
# epochs: 200

# %%
experiment = Experiment(qubit_initial=0, cavity_initial=1, superposition=True, n_samples=1000, n_times=1000, t_i=0, t_f=10)
experiment.Run_system(model='BiLSTM', epochs=150, batch_size=100)
experiment.Run_system(model='Transformer_conv', epochs=150, batch_size=100)
# Out:
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4842 - binary_crossentropy: 0.4842
# train loss: 0.48418739438056946
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4846 - binary_crossentropy: 0.4844
# test loss: 0.48462098836898804
# rmse: 0.015964247042049847
# r2: 0.9896216829722895
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4844 - binary_crossentropy: 0.4843
# train loss: 0.4843688905239105
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4846 - binary_crossentropy: 0.4845
# test loss: 0.48455944657325745
# rmse: 0.020036367753785107
# r2: 0.9833879283102769
