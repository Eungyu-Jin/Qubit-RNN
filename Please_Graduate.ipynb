# %%
from Please_Graduate import Quantum_System, Models, Experiment
import numpy as np

#experimental setting
omega_r = 2*np.pi*0.80
kai = -2*np.pi*0.18

#model fit setting
split_ratio = 0.75
time_step = 10
n_samples = 100
n_times = 100
t_i, t_f = 0, 1

#transformer setting
key_dim = 256
num_heads = 4
ff_dim = 128
num_blocks = 1

# %%
experiment = Experiment(qubit_initial=0, cavity_initial=1, superposition=True, n_samples=100, n_times=100, t_i=0, t_f=1)

# %%
experiment.Run_system(model = 'LSTM', epochs=100, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5591 - binary_crossentropy: 0.5669
# train loss: 0.559127688407898
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5546 - binary_crossentropy: 0.5546
# test loss: 0.554575502872467
# rmse: 0.1617510003257483
# r2: -0.015521901914011454

# %%
experiment.Run_system(model = 'BiLSTM', epochs=100, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5550 - binary_crossentropy: 0.5643
# train loss: 0.5549726486206055
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5520 - binary_crossentropy: 0.5520
# test loss: 0.5520278215408325
# rmse: 0.1563919896364703
# r2: 0.045978389280564025

# %%
experiment.Run_system(model = 'Transformer', epochs=100, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4983 - binary_crossentropy: 0.5172
# train loss: 0.4982835650444031
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5052 - binary_crossentropy: 0.5052
# test loss: 0.5051679015159607
# rmse: 0.07900432567490223
# r2: 0.7578616426902716

# %%
experiment.Run_system(model = 'Transformer_conv', epochs=100, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4914 - binary_crossentropy: 0.5023
# train loss: 0.4914443790912628
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000249509F2AF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4879 - binary_crossentropy: 0.4879
# ...

# %%
experiment.Run_system(model = 'Transformer_conv', epochs=150, batch_size=100)
# Out:
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4881 - binary_crossentropy: 0.4957
# train loss: 0.48808324337005615
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000024976444EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4914 - binary_crossentropy: 0.4914
# ...

# %%
experiment = Experiment(qubit_initial=0, cavity_initial=1, superposition=True, n_samples=100, n_times=100, t_i=0, t_f=1)
for e in [10,50,100,150,200]:
    experiment.Run_system(model = 'BiLSTM', epochs=e, batch_size=100)
    print('epochs: {}'.format(e))
# Out:
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6680 - binary_crossentropy: 0.6680
# train loss: 0.667962372303009
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6679 - binary_crossentropy: 0.6679
# test loss: 0.6679233312606812
# rmse: 0.27902612482209754
# r2: -2.380603531203124
# epochs: 10
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5604 - binary_crossentropy: 0.5724
# train loss: 0.5604143142700195
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5538 - binary_crossentropy: 0.5538
# test loss: 0.5538448095321655
# rmse: 0.16082676204756563
# r2: -6.253722611873624e-05
# epochs: 50
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5556 - binary_crossentropy: 0.5635
# train loss: 0.5556255578994751
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5520 - binary_crossentropy: 0.5520
# test loss: 0.5520197749137878
# rmse: 0.15934799682414513
# r2: 0.04106312586676952
# epochs: 100
# ...

# %%
experiment = Experiment(qubit_initial=0, cavity_initial=1, superposition=True, n_samples=1000, n_times=1000, t_i=0, t_f=10)
experiment.Run_system(model='BiLSTM', epochs=150, batch_size=100)
experiment.Run_system(model='Transformer_conv', epochs=150, batch_size=100)
# Out:
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4865 - binary_crossentropy: 0.4865
# train loss: 0.4865359365940094
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4864 - binary_crossentropy: 0.4862
# test loss: 0.4864363968372345
# rmse: 0.025124620870165593
# r2: 0.9738923631871237
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4842 - binary_crossentropy: 0.4841
# train loss: 0.48422351479530334
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4839 - binary_crossentropy: 0.4836
# test loss: 0.4839140772819519
# rmse: 0.019109510995924325
# r2: 0.9851661911809039
